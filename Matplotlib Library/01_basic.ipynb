# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 8, 7]

plt.plot(x,y,label='Line')
plt.xlabel('X-axis')
plt.ylabel('Y-label')
plt.title('Basic Line plot')
plt.legend()
plt.show()
